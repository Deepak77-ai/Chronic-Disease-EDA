# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('kidney_disease.csv')
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (400, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df.drop('id', axis = 1, inplace = True)#In Exploratory Data Analysis (EDA), we often drop columns like id or name because they are not useful for modeling or analysis.#
# inplace=True means that the operation is performed on the original DataFrame, not a copy.

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.columns = ['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell',
              'pus_cell_clumps', 'bacteria', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
              'potassium', 'haemoglobin', 'packed_cell_volume', 'white_blood_cell_count', 'red_blood_cell_count',
              'hypertension', 'diabetes_mellitus', 'coronary_artery_disease', 'appetite', 'peda_edema',
              'aanemia', 'class']

# %%
df
# Out:
#       age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0    48.0            80.0             1.020      1.0    0.0             NaN
# 1     7.0            50.0             1.020      4.0    0.0             NaN
# 2    62.0            80.0             1.010      2.0    3.0          normal
# 3    48.0            70.0             1.005      4.0    0.0          normal
# 4    51.0            80.0             1.010      2.0    0.0          normal
# ..    ...             ...               ...      ...    ...             ...
# 395  55.0            80.0             1.020      0.0    0.0          normal
# 396  42.0            70.0             1.025      0.0    0.0          normal
# 397  12.0            80.0             1.020      0.0    0.0          normal
# 398  17.0            60.0             1.025      0.0    0.0          normal
# 399  58.0            80.0             1.025      0.0    0.0          normal
#
# ...

# %%
df.describe()
# Out:
#               age  blood_pressure  specific_gravity     albumin       sugar  \
# count  391.000000      388.000000        353.000000  354.000000  351.000000
# mean    51.483376       76.469072          1.017408    1.016949    0.450142
# std     17.169714       13.683637          0.005717    1.352679    1.099191
# min      2.000000       50.000000          1.005000    0.000000    0.000000
# 25%     42.000000       70.000000          1.010000    0.000000    0.000000
# 50%     55.000000       80.000000          1.020000    0.000000    0.000000
# 75%     64.500000       80.000000          1.020000    2.000000    0.000000
# max     90.000000      180.000000          1.025000    5.000000    5.000000
#
#        blood_glucose_random  blood_urea  serum_creatinine      sodium  \
# count            356.000000  381.000000        383.000000  313.000000
# mean             148.036517   57.425722          3.072454  137.528754
# std               79.281714   50.503006          5.741126   10.408752
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      391 non-null    float64
#  1   blood_pressure           388 non-null    float64
#  2   specific_gravity         353 non-null    float64
#  3   albumin                  354 non-null    float64
#  4   sugar                    351 non-null    float64
#  5   red_blood_cells          248 non-null    object
#  6   pus_cell                 335 non-null    object
#  7   pus_cell_clumps          396 non-null    object
#  8   bacteria                 396 non-null    object
#  9   blood_glucose_random     356 non-null    float64
#  10  blood_urea               381 non-null    float64
#  11  serum_creatinine         383 non-null    float64
#  12  sodium                   313 non-null    float64
#  13  potassium                312 non-null    float64
# ...

# %%
df['packed_cell_volume'] = pd.to_numeric(df['packed_cell_volume'], errors = 'coerce')#errors = 'coerce'>>“If there is a value that cannot be converted to a number, then replace it with NaN (Not a Number).”

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      391 non-null    float64
#  1   blood_pressure           388 non-null    float64
#  2   specific_gravity         353 non-null    float64
#  3   albumin                  354 non-null    float64
#  4   sugar                    351 non-null    float64
#  5   red_blood_cells          248 non-null    object
#  6   pus_cell                 335 non-null    object
#  7   pus_cell_clumps          396 non-null    object
#  8   bacteria                 396 non-null    object
#  9   blood_glucose_random     356 non-null    float64
#  10  blood_urea               381 non-null    float64
#  11  serum_creatinine         383 non-null    float64
#  12  sodium                   313 non-null    float64
#  13  potassium                312 non-null    float64
# ...

# %%
df['white_blood_cell_count'] = pd.to_numeric(df['white_blood_cell_count'], errors = 'coerce')

df['red_blood_cell_count'] = pd.to_numeric(df['red_blood_cell_count'], errors = 'coerce')

# %%
df.dtypes
# Out:
# age                        float64
# blood_pressure             float64
# specific_gravity           float64
# albumin                    float64
# sugar                      float64
# red_blood_cells             object
# pus_cell                    object
# pus_cell_clumps             object
# bacteria                    object
# blood_glucose_random       float64
# blood_urea                 float64
# serum_creatinine           float64
# sodium                     float64
# potassium                  float64
# haemoglobin                float64
# packed_cell_volume         float64
# white_blood_cell_count     float64
# red_blood_cell_count       float64
# hypertension                object
# diabetes_mellitus           object
# coronary_artery_disease     object
# appetite                    object
# peda_edema                  object
# aanemia                     object
# class                       object
# dtype: object

# %%
cat_cols = [col for col in df.columns if df[col].dtype == "object"]
num_cols = [col for col in df.columns if df[col].dtype != "object"]

# %%
cat_cols
# Out:
# ['red_blood_cells',
#  'pus_cell',
#  'pus_cell_clumps',
#  'bacteria',
#  'hypertension',
#  'diabetes_mellitus',
#  'coronary_artery_disease',
#  'appetite',
#  'peda_edema',
#  'aanemia',
#  'class']

# %%
num_cols
# Out:
# ['age',
#  'blood_pressure',
#  'specific_gravity',
#  'albumin',
#  'sugar',
#  'blood_glucose_random',
#  'blood_urea',
#  'serum_creatinine',
#  'sodium',
#  'potassium',
#  'haemoglobin',
#  'packed_cell_volume',
#  'white_blood_cell_count',
#  'red_blood_cell_count']

# %%
for col in cat_cols:
    print(f"{col} has {df[col].unique()} values \n")
# Out:
# red_blood_cells has [nan 'normal' 'abnormal'] values
#
# pus_cell has ['normal' 'abnormal' nan] values
#
# pus_cell_clumps has ['notpresent' 'present' nan] values
#
# bacteria has ['notpresent' 'present' nan] values
#
# hypertension has ['yes' 'no' nan] values
#
# diabetes_mellitus has ['yes' 'no' ' yes' '\tno' '\tyes' nan] values
#
# coronary_artery_disease has ['no' 'yes' '\tno' nan] values
#
# appetite has ['good' 'poor' nan] values
#
# peda_edema has ['no' 'yes' nan] values
#
# aanemia has ['no' 'yes' nan] values
#
# class has ['ckd' 'ckd\t' 'notckd'] values

# %%
#replace unwanted values

df['diabetes_mellitus'].replace(to_replace = {' yes':'yes', '\tyes': 'yes', '\tno': 'no'}, inplace = True)

# %%
df['diabetes_mellitus'].unique()
# Out:
# array(['yes', 'no', nan], dtype=object)

# %%
df['coronary_artery_disease'] = df['coronary_artery_disease'].replace(to_replace = '\tno', value = 'no')

# %%
df['coronary_artery_disease'].unique()
# Out:
# array(['no', 'yes', nan], dtype=object)

# %%
df['class'] = df['class'].replace(to_replace = 'ckd\t', value = 'ckd')

# %%
df['class'].unique()
# Out:
# array(['ckd', 'notckd'], dtype=object)

# %%
df['class'] = df['class'].map({'ckd': 0, 'notckd': 1})

# %%
df['class'].unique()
# Out:
# array([0, 1])

# %%
for col in cat_cols:
    print(f"{col} has {df[col].unique()} values \n")
# Out:
# red_blood_cells has [nan 'normal' 'abnormal'] values
#
# pus_cell has ['normal' 'abnormal' nan] values
#
# pus_cell_clumps has ['notpresent' 'present' nan] values
#
# bacteria has ['notpresent' 'present' nan] values
#
# hypertension has ['yes' 'no' nan] values
#
# diabetes_mellitus has ['yes' 'no' nan] values
#
# coronary_artery_disease has ['no' 'yes' nan] values
#
# appetite has ['good' 'poor' nan] values
#
# peda_edema has ['no' 'yes' nan] values
#
# aanemia has ['no' 'yes' nan] values
#
# class has [0 1] values

# %%
#Univariate

plt.figure(figsize = (10, 6))
sns.histplot(df['age'].dropna(), kde = True, bins = 20, color = 'skyblue')
plt.title('Dist of age')
plt.xlabel('Age')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# histplot>>
#
# Primarily used for: Numerical data
#
# histplot is designed to show distribution (frequency) of continuous numerical values.
#
# It divides values into bins (ranges) and shows how many fall into each.
# ___________________

# %% [markdown]
# | **Type of Analysis** | **No. of Variables** | **Data Type**               | **Common Plots / Visualizations**          | **Purpose**                                                           |
# | -------------------- | -------------------- | --------------------------- | ------------------------------------------ | --------------------------------------------------------------------- |
# | **Univariate**       | 1                    | **Numerical**               | Histogram, Box Plot, KDE Plot, Violin Plot | To study distribution, central tendency, and outliers of one variable |
# |                      |                      | **Categorical**             | Bar Plot, Count Plot, Pie Chart            | To study frequency or proportion of each category                     |
# | **Bivariate**        | 2                    | **Numerical–Numerical**     | Scatter Plot, Line Plot                    | To study relationship or correlation between two numerical variables  |
# |                      |                      | **Categorical–Numerical**   | Box Plot, Violin Plot, Bar Plot            | To compare numerical values across categories                         |
# |                      |                      | **Categorical–Categorical** | Heatmap, Clustered Bar Plot                | To compare frequency relationships between two categorical variables  |
# | **Multivariate**     | 3 or more            | **Mixed Data**              | Pair Plot, Heatmap (correlation), 3D Plot  | To study complex relationships among multiple variables               |

# %%
#insighst>> dist of age is right skewed

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.countplot(x = 'hypertension', data = df, palette = 'viridis')
# Out:
# <Axes: xlabel='hypertension', ylabel='count'>

# %%
#150 of them has hypertension

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.boxplot(x = 'class', y = 'blood_urea', data = df, palette = 'viridis')
# Out:
# <Axes: xlabel='class', ylabel='blood_urea'>

# %%
#insights>> outliers

# %%
sns.violinplot(x = 'class', y = 'serum_creatinine', data = df, palette = "muted")
# Out:
# <Axes: xlabel='class', ylabel='serum_creatinine'>

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.countplot(x = 'aanemia', data = df, palette = 'pastel')
# Out:
# <Axes: xlabel='aanemia', ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
df.appetite.value_counts().plot.pie(autopct = '%1.1f%%', colors = ['lightcoral', 'lightgreen'], explode = (0, 0.1), startangle = 90, shadow = True)
#.plot gives you access to plotting functions like .plot.pie(), .plot.bar(), .plot.line(), etc.
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(x = 'pus_cell_clumps', data = df)
# Out:
# <Axes: xlabel='pus_cell_clumps', ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.histplot(df['white_blood_cell_count'].dropna(), bins = 20, kde = True, color = 'darkorange')
# Out:
# <Axes: xlabel='white_blood_cell_count', ylabel='Count'>

# %% [markdown]
# histplot>>
#
# Primarily used for: Numerical data
#
# histplot is designed to show distribution (frequency) of continuous numerical values.
#
# It divides values into bins (ranges) and shows how many fall into each.
# ___________________

# %%
df['diabetes_mellitus'].value_counts().plot.pie(autopct = "%1.1f%%", wedgeprops = dict(width=0.3))
# wedgeprops = dict(width=0.3)>>This line creates a dictionary named wedgeprops with one key-value pair
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.countplot(x = 'coronary_artery_disease', data = df)
# Out:
# <Axes: xlabel='coronary_artery_disease', ylabel='count'>

# %%
sns.countplot(x = 'peda_edema', data = df)
# Out:
# <Axes: xlabel='peda_edema', ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.countplot(x = 'bacteria', data=df)
# Out:
# <Axes: xlabel='bacteria', ylabel='count'>

# %%
#bivariate analysis

sns.scatterplot(x = 'age', y = 'blood_pressure', data = df)
# Out:
# <Axes: xlabel='age', ylabel='blood_pressure'>

# %% [markdown]
# Scatter plot is used to visualize the relationship, correlation, and pattern between two continuous variables.
#
# it is bivariate

# %%
sns.scatterplot(x = 'age', y = 'blood_pressure', data = df, hue = 'class', palette = 'coolwarm')
# Out:
# <Axes: xlabel='age', ylabel='blood_pressure'>

# %%
#as age is increasing, bp is increasing

# %%
sns.boxplot(x = 'diabetes_mellitus', y = 'albumin', data =df)
# Out:
# <Axes: xlabel='diabetes_mellitus', ylabel='albumin'>

# %%
sns.violinplot(x = 'diabetes_mellitus', y = 'albumin', data =df, inner= 'quartile')
# Out:
# <Axes: xlabel='diabetes_mellitus', ylabel='albumin'>

# %%
#stacked bar chart
diabetes_hypertension = pd.crosstab(df['diabetes_mellitus'], df['hypertension'])

diabetes_hypertension.plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='diabetes_mellitus'>

# %%
#multivariate analysis

cols = ['age', 'blood_pressure', 'blood_glucose_random', 'serum_creatinine', 'class']

g = sns.PairGrid(df[cols], hue='class', palette = 'coolwarm')
#PairGrid is a powerful tool for creating a matrix of plots showing relationships between multiple variables. 
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot, cmap = 'Blues_d')
g.map_diag(sns.histplot)
g.add_legend()
plt.title("PairGrid for selected columns")
plt.show()

# %% [markdown]
# cmap → stands for colormap (a range of colors used to represent values).
#
# 'Blues' → is a predefined sequential colormap in Matplotlib, going from light blue (low values) to dark blue (high values).
#
# '_d' (the “d” suffix) → means discrete. Instead of a smooth gradient, it creates discrete color steps (categories).

# %%
cols = ['age', 'blood_pressure', 'blood_glucose_random', 'serum_creatinine', 'class']
sns.pairplot(df[cols], hue = 'class', palette = 'husl')

# %%
df.corr(numeric_only=True)
# Out:
#                              age  blood_pressure  specific_gravity   albumin  \
# age                     1.000000        0.159480         -0.191096  0.122091
# blood_pressure          0.159480        1.000000         -0.218836  0.160689
# specific_gravity       -0.191096       -0.218836          1.000000 -0.469760
# albumin                 0.122091        0.160689         -0.469760  1.000000
# sugar                   0.220866        0.222576         -0.296234  0.269305
# blood_glucose_random    0.244992        0.160193         -0.374710  0.379464
# blood_urea              0.196985        0.188517         -0.314295  0.453528
# serum_creatinine        0.132531        0.146222         -0.361473  0.399198
# sodium                 -0.100046       -0.116422          0.412190 -0.459896
# potassium               0.058377        0.075151         -0.072787  0.129038
# haemoglobin            -0.192928       -0.306540          0.602582 -0.634632
# ...

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize = (12, 8))
sns.heatmap(corr, annot = True, cmap = 'coolwarm', linewidth = .5)
# Out:
# <Axes: >

# %%
sns.swarmplot(x='diabetes_mellitus', y='age', hue='hypertension', data=df, palette='pastel', size=8)
# Out:
# <Axes: xlabel='diabetes_mellitus', ylabel='age'>

# %% [markdown]
# A swarmplot shows each individual data point in a dataset arranged so that no points overlap.
#
# ✔️ Best for showing:
#
# Real data points (not summarized)
#
# How values are spread for each category
#
# Clusters, gaps, and outliers clearly
#
# Sample size for each category
#
#
# Swarmplot is used to show individual data points for categories without overlap, making the distribution crystal clear.

# %%
fig = px.scatter(df, x = 'age', y = 'blood_pressure', color = 'class', hover_data = ['serum_creatinine', 'haemoglobin'],title = "interactive scatterplot with hover information")
fig.show()

# %%
fig = px.scatter_3d(df, x = 'age', y = 'blood_pressure',z = 'serum_creatinine', color = 'class', title = "3d scatter plot scatterplot")
fig.show()

# %%
import plotly.graph_objects as go

data_corr = df.corr(numeric_only = True)
fig = go.Figure(data =go.Heatmap(z = data_corr.values,
                          x = data_corr.columns,
                          y=data_corr.index))
fig.show()

# %%
fig = px.scatter_3d(df, x='age', y='blood_pressure', z='serum_creatinine', color='haemoglobin',
                    title='3D Scatter plot with Color Gradient')
fig.show()

# %%
df.isnull().sum()
# Out:
# age                          9
# blood_pressure              12
# specific_gravity            47
# albumin                     46
# sugar                       49
# red_blood_cells            152
# pus_cell                    65
# pus_cell_clumps              4
# bacteria                     4
# blood_glucose_random        44
# blood_urea                  19
# serum_creatinine            17
# sodium                      87
# potassium                   88
# haemoglobin                 52
# packed_cell_volume          71
# white_blood_cell_count     106
# red_blood_cell_count       131
# hypertension                 2
# diabetes_mellitus            2
# coronary_artery_disease      2
# appetite                     1
# peda_edema                   1
# aanemia                      1
# class                        0
# dtype: int64

# %%
cat_cols
# Out:
# ['red_blood_cells',
#  'pus_cell',
#  'pus_cell_clumps',
#  'bacteria',
#  'hypertension',
#  'diabetes_mellitus',
#  'coronary_artery_disease',
#  'appetite',
#  'peda_edema',
#  'aanemia',
#  'class']

# %%
num_cols
# Out:
# ['age',
#  'blood_pressure',
#  'specific_gravity',
#  'albumin',
#  'sugar',
#  'blood_glucose_random',
#  'blood_urea',
#  'serum_creatinine',
#  'sodium',
#  'potassium',
#  'haemoglobin',
#  'packed_cell_volume',
#  'white_blood_cell_count',
#  'red_blood_cell_count']

# %%
#replace with median
median_values = df[num_cols].median()

# %%
median_values
# Out:
# age                         55.00
# blood_pressure              80.00
# specific_gravity             1.02
# albumin                      0.00
# sugar                        0.00
# blood_glucose_random       121.00
# blood_urea                  42.00
# serum_creatinine             1.30
# sodium                     138.00
# potassium                    4.40
# haemoglobin                 12.65
# packed_cell_volume          40.00
# white_blood_cell_count    8000.00
# red_blood_cell_count         4.80
# dtype: float64

# %%
df[num_cols] = df[num_cols].fillna(median_values)

# %%
df[num_cols].isna().sum()
# Out:
# age                       0
# blood_pressure            0
# specific_gravity          0
# albumin                   0
# sugar                     0
# blood_glucose_random      0
# blood_urea                0
# serum_creatinine          0
# sodium                    0
# potassium                 0
# haemoglobin               0
# packed_cell_volume        0
# white_blood_cell_count    0
# red_blood_cell_count      0
# dtype: int64

# %%
mode_values = df.mode().iloc[0]
df[cat_cols] = df[cat_cols].fillna(mode_values)

# %%
df[cat_cols].isna().sum()
# Out:
# red_blood_cells            0
# pus_cell                   0
# pus_cell_clumps            0
# bacteria                   0
# hypertension               0
# diabetes_mellitus          0
# coronary_artery_disease    0
# appetite                   0
# peda_edema                 0
# aanemia                    0
# class                      0
# dtype: int64

# %%
df.dtypes
# Out:
# age                        float64
# blood_pressure             float64
# specific_gravity           float64
# albumin                    float64
# sugar                      float64
# red_blood_cells             object
# pus_cell                    object
# pus_cell_clumps             object
# bacteria                    object
# blood_glucose_random       float64
# blood_urea                 float64
# serum_creatinine           float64
# sodium                     float64
# potassium                  float64
# haemoglobin                float64
# packed_cell_volume         float64
# white_blood_cell_count     float64
# red_blood_cell_count       float64
# hypertension                object
# diabetes_mellitus           object
# coronary_artery_disease     object
# appetite                    object
# peda_edema                  object
# aanemia                     object
# class                        int64
# dtype: object

# %%
#encoding
from sklearn.preprocessing import LabelEncoder

# %%
LabelEncoder = LabelEncoder()
for col in cat_cols:
    df[col] = LabelEncoder.fit_transform(df[col])

# %%
df.head()
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar  red_blood_cells  \
# 0  48.0            80.0             1.020      1.0    0.0                1
# 1   7.0            50.0             1.020      4.0    0.0                1
# 2  62.0            80.0             1.010      2.0    3.0                1
# 3  48.0            70.0             1.005      4.0    0.0                1
# 4  51.0            80.0             1.010      2.0    0.0                1
#
#    pus_cell  pus_cell_clumps  bacteria  blood_glucose_random  ...  \
# 0         1                0         0                 121.0  ...
# 1         1                0         0                 121.0  ...
# 2         1                0         0                 423.0  ...
# 3         0                1         0                 117.0  ...
# 4         1                0         0                 106.0  ...
#
#    packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# ...

# %%
X = df.drop('class', axis = 1)
y = df['class']

# %%
#train-test split and ml model training
